# %%
# !pip install --upgrade tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.7.0-cp39-cp39-macosx_10_11_x86_64.whl (207.1 MB)
#      |████████████████████████████████| 207.1 MB 15 kB/s s eta 0:00:01   |█▋                              | 10.1 MB 2.1 MB/s eta 0:01:36     |██████████▌                     | 68.1 MB 13.0 MB/s eta 0:00:11     |███████████████████▌            | 126.5 MB 15.3 MB/s eta 0:00:06     |███████████████████▋            | 127.1 MB 15.3 MB/s eta 0:00:06     |██████████████████████▉         | 148.1 MB 9.2 MB/s eta 0:00:07     |███████████████████████████████▌| 204.2 MB 15.2 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.10.0.2)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: h5py>=2.9.0 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.2.1)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.1-cp39-cp39-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 12.7 MB/s eta 0:00:01
# Collecting gast<0.5.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting libclang>=9.0.1
#   Downloading libclang-12.0.0-py2.py3-none-macosx_10_9_x86_64.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 10.7 MB/s eta 0:00:01
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 19.2 MB/s eta 0:00:01
# Requirement already satisfied: wrapt>=1.11.0 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Downloading tensorflow_io_gcs_filesystem-0.23.1-cp39-cp39-macosx_10_14_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 16.8 MB/s eta 0:00:01     |████████▉                       | 450 kB 16.8 MB/s eta 0:00:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 7.5 MB/s  eta 0:00:01
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.37.0)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 24.2 MB/s eta 0:00:01
# Collecting absl-py>=0.4.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 17.2 MB/s eta 0:00:01
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 8.7 MB/s  eta 0:00:01
# Requirement already satisfied: six>=1.12.0 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 2.7 MB/s  eta 0:00:01
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 13.8 MB/s eta 0:00:01
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.43.0-cp39-cp39-macosx_10_10_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 21.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.20.3)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 19.4 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (2.0.2)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (58.0.4)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.3.3-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 17.2 MB/s eta 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 11.3 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 12.2 MB/s eta 0:00:01     |████▌                           | 501 kB 12.2 MB/s eta 0:00:01
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 17.4 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 8.6 MB/s  eta 0:00:01
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/shubham/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=7b9580721f5d8b3fc23f1f806d45ccdeb94e16e8f080ed87d5b0b48da7391339
#   Stored in directory: /Users/shubham/Library/Caches/pip/wheels/b6/0d/90/0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# Installing collected packages: pyasn1, rsa, pyasn1-modules, cachetools, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-4.2.4 flatbuffers-2.0 gast-0.4.0 google-auth-2.3.3 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.43.0 keras-2.7.0 keras-preprocessing-1.1.2 libclang-12.0.0 markdown-3.3.6 opt-einsum-3.3.0 protobuf-3.19.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.8 tensorboard-2.7.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.23.1 termcolor-1.1.0

# %%
import tensorflow
from  tensorflow import keras
print('TensorFlow version:',tensorflow.__version__)
print('Keras version:',keras.__version__)
# Out:
# TensorFlow version: 2.7.0
# Keras version: 2.7.0

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from pathlib import Path
# %matplotlib inline

# The images are in the data/shapes folder
data_folder = os.path.join('shubham.ss1608/data/abc')

# Get the class names
classes = os.listdir(data_folder)
classes.sort()
print(len(classes), 'classes:')
print(classes)

# Show the first image in each folder
fig = plt.figure(figsize=(8, 12))
i = 0
for sub_dir in os.listdir(data_folder):
    i+=1
    img_file = os.listdir(os.path.join(data_folder,sub_dir))[1]
    img_path = os.path.join(data_folder, sub_dir, img_file)
    img = mpimg.imread(img_path)
    a=fig.add_subplot(1, len(classes),i)
    a.axis('off')
    imgplot = plt.imshow(img)
    a.set_title(img_file)
plt.show()
# Out:
# 3 classes:
# ['0', '1', '2']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = (128, 128)
batch_size = 30

print("Getting Data...")
datagen = ImageDataGenerator(rescale=1./255, # normalize pixel values
                             validation_split=0.3) # hold back 30% of the images for validation

print("Preparing training dataset...")
train_generator = datagen.flow_from_directory(
    data_folder,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training') # set as training data

print("Preparing validation dataset...")
validation_generator = datagen.flow_from_directory(
    data_folder,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation') # set as validation data

classnames = list(train_generator.class_indices.keys())
print('Data generators ready')
# Out:
# Getting Data...
# Preparing training dataset...
# Found 172 images belonging to 3 classes.
# Preparing validation dataset...
# Found 72 images belonging to 3 classes.
# Data generators ready

# %%
# Define a CNN classifier network
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

# Define the model as a sequence of layers
model = Sequential()

# The input layer accepts an image and applies a convolution that uses 32 6x6 filters and a rectified linear unit activation function
model.add(Conv2D(32, (6, 6), input_shape=train_generator.image_shape, activation='relu'))

# Next we'll add a max pooling layer with a 2x2 patch
model.add(MaxPooling2D(pool_size=(2,2)))

# We can add as many layers as we think necessary - here we'll add another convolution and max pooling layer
model.add(Conv2D(32, (6, 6), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# And another set
model.add(Conv2D(32, (6, 6), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# A dropout layer randomly drops some nodes to reduce inter-dependencies (which can cause over-fitting)
model.add(Dropout(0.2))

# Flatten the feature maps 
model.add(Flatten())

# Generate a fully-connected output layer with a predicted probability for each class
# (softmax ensures all probabilities sum to 1)
model.add(Dense(train_generator.num_classes, activation='softmax'))

# With the layers defined, we can now compile the model for categorical (multi-class) classification
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 123, 123, 32)      3488
#
#  max_pooling2d (MaxPooling2D  (None, 61, 61, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 32)        36896
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 32)        36896
#
#  max_pooling2d_2 (MaxPooling  (None, 11, 11, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 32)        0
#
#  flatten (Flatten)           (None, 3872)              0
#
#  dense (Dense)               (None, 3)                 11619
#
# =================================================================
# Total params: 88,899
# Trainable params: 88,899
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
num_epochs = 25
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = num_epochs)
# Out:
# Epoch 1/25
# 5/5 [==============================] - 12s 2s/step - loss: 1.1016 - accuracy: 0.3662 - val_loss: 1.0691 - val_accuracy: 0.4167
# Epoch 2/25
# 5/5 [==============================] - 8s 2s/step - loss: 1.0545 - accuracy: 0.4267 - val_loss: 1.0147 - val_accuracy: 0.4667
# Epoch 3/25
# 5/5 [==============================] - 9s 2s/step - loss: 1.0550 - accuracy: 0.4789 - val_loss: 1.0217 - val_accuracy: 0.4667
# Epoch 4/25
# 5/5 [==============================] - 8s 1s/step - loss: 1.0101 - accuracy: 0.5986 - val_loss: 1.0023 - val_accuracy: 0.5667
# Epoch 5/25
# 5/5 [==============================] - 8s 1s/step - loss: 0.9883 - accuracy: 0.6127 - val_loss: 1.0209 - val_accuracy: 0.4500
# Epoch 6/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.9279 - accuracy: 0.5845 - val_loss: 1.0139 - val_accuracy: 0.5333
# Epoch 7/25
# 5/5 [==============================] - 10s 2s/step - loss: 0.8858 - accuracy: 0.6197 - val_loss: 0.9519 - val_accuracy: 0.5333
# Epoch 8/25
# 5/5 [==============================] - 9s 2s/step - loss: 0.8476 - accuracy: 0.6867 - val_loss: 1.0146 - val_accuracy: 0.5833
# Epoch 9/25
# 5/5 [==============================] - 9s 2s/step - loss: 0.7691 - accuracy: 0.6901 - val_loss: 0.9946 - val_accuracy: 0.5167
# Epoch 10/25
# 5/5 [==============================] - 9s 2s/step - loss: 0.6756 - accuracy: 0.7042 - val_loss: 1.1175 - val_accuracy: 0.6000
# Epoch 11/25
# 5/5 [==============================] - 9s 2s/step - loss: 0.7231 - accuracy: 0.6479 - val_loss: 0.8277 - val_accuracy: 0.6167
# Epoch 12/25
# 5/5 [==============================] - 9s 2s/step - loss: 0.5737 - accuracy: 0.7535 - val_loss: 0.8655 - val_accuracy: 0.6667
# Epoch 13/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.5208 - accuracy: 0.8310 - val_loss: 0.7548 - val_accuracy: 0.5667
# Epoch 14/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.4237 - accuracy: 0.8933 - val_loss: 0.7658 - val_accuracy: 0.7167
# Epoch 15/25
# 5/5 [==============================] - 8s 1s/step - loss: 0.3314 - accuracy: 0.8803 - val_loss: 0.8038 - val_accuracy: 0.7167
# Epoch 16/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.2947 - accuracy: 0.9014 - val_loss: 0.7627 - val_accuracy: 0.7833
# Epoch 17/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.2630 - accuracy: 0.9014 - val_loss: 0.9075 - val_accuracy: 0.6333
# Epoch 18/25
# 5/5 [==============================] - 8s 1s/step - loss: 0.2374 - accuracy: 0.9225 - val_loss: 0.5723 - val_accuracy: 0.7833
# Epoch 19/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.1622 - accuracy: 0.9533 - val_loss: 0.9618 - val_accuracy: 0.7333
# Epoch 20/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.1200 - accuracy: 0.9733 - val_loss: 0.7058 - val_accuracy: 0.7833
# Epoch 21/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.1255 - accuracy: 0.9718 - val_loss: 0.8031 - val_accuracy: 0.7500
# Epoch 22/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.1296 - accuracy: 0.9577 - val_loss: 0.8100 - val_accuracy: 0.7833
# Epoch 23/25
# 5/5 [==============================] - 8s 1s/step - loss: 0.0833 - accuracy: 0.9859 - val_loss: 0.9440 - val_accuracy: 0.7667
# Epoch 24/25
# 5/5 [==============================] - 8s 1s/step - loss: 0.0739 - accuracy: 0.9718 - val_loss: 1.0570 - val_accuracy: 0.7667
# Epoch 25/25
# 5/5 [==============================] - 8s 2s/step - loss: 0.0578 - accuracy: 0.9859 - val_loss: 0.7978 - val_accuracy: 0.8167

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

epoch_nums = range(1,num_epochs+1)
training_loss = history.history["loss"]
validation_loss = history.history["val_loss"]
plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

epoch_nums = range(1,num_epochs+1)
training_loss = history.history["val_accuracy"]
validation_loss = history.history["val_loss"]
plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

epoch_nums = range(1,num_epochs+1)
training_loss = history.history["accuracy"]
validation_loss = history.history["loss"]
plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

print("Generating predictions from validation data...")
# Get the image and label arrays for the first batch of validation data
x_test = validation_generator[0][0]
y_test = validation_generator[0][1]

# Use the model to predict the class
class_probabilities = model.predict(x_test)

# The model returns a probability value for each class
# The one with the highest probability is the predicted class
predictions = np.argmax(class_probabilities, axis=1)

# The actual labels are hot encoded (e.g. [0 1 0], so get the one with the value 1
true_labels = np.argmax(y_test, axis=1)

# Plot the confusion matrix
cm = confusion_matrix(true_labels, predictions)
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.colorbar()
tick_marks = np.arange(len(classnames))
plt.xticks(tick_marks, classnames, rotation=85)
plt.yticks(tick_marks, classnames)
plt.xlabel("Predicted Shape")
plt.ylabel("Actual Shape")
plt.show()
# Out:
# Generating predictions from validation data...

# %%
modelFileName = 'models/shape_classifier.h5'
model.save(modelFileName)
del model  # deletes the existing model variable
print('model saved as', modelFileName)
# Out:
# model saved as models/shape_classifier.h5

# %%
from tensorflow.keras import models
import numpy as np
from random import randint
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# Function to predict the class of an image
def predict_image(classifier, image):
    from tensorflow import convert_to_tensor
    # The model expects a batch of images as input, so we'll create an array of 1 image
    imgfeatures = image.reshape(1, image.shape[0], image.shape[1], image.shape[2])

    # We need to format the input to match the training data
    # The generator loaded the values as floating point numbers
    # and normalized the pixel values, so...
    imgfeatures = imgfeatures.astype('float32')
    imgfeatures /= 255
    
    # Use the model to predict the image class
    class_probabilities = classifier.predict(imgfeatures)
    
    # Find the class predictions with the highest predicted probability
    index = int(np.argmax(class_probabilities, axis=1)[0])
    return index

# Function to create a random image (of a square, circle, or triangle)
def create_image (size, shape):
    from random import randint
    import numpy as np
    from PIL import Image, ImageDraw
    
    xy1 = randint(10,40)
    xy2 = randint(60,100)
    col = (randint(0,200), randint(0,200), randint(0,200))

    img = Image.new("RGB", size, (255, 255, 255))
    draw = ImageDraw.Draw(img)
    
    if shape == '0':
        draw.ellipse([(xy1,xy1), (xy2,xy2)], fill=col)
    elif shape == '1':
        draw.polygon([(xy1,xy1), (xy2,xy2), (xy2,xy1)], fill=col)
    else: # square
        draw.rectangle([(xy1,xy1), (xy2,xy2)], fill=col)
    del draw
    
    return np.array(img)

# Create a random test image
classnames = os.listdir(os.path.join('shubham.ss1608/data/abc'))
classnames.sort()
img = create_image ((128,128), classnames[randint(0, len(classnames)-1)])
#plt.axis('off')
plt.imshow(img)

# Use the classifier to predict the class
#model = models.load_model(modelFileName) # loads the saved model
#class_idx = predict_image(model, img)
#print (classnames[class_idx])

# %% [markdown]
# ![Screenshot 2022-01-03 at 7.27.13 AM.png](attachment:d7e5bd27-b1b0-477b-8c3f-20c49e60966d.png)
